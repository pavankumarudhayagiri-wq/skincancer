# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/adedi/OneDrive - Solent University/Diss/Dissertation/Dataset/Source_2/metadata.csv')

df
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0      PAT_1516       1765    NaN    NaN               NaN               NaN
# 1        PAT_46        881  False  False         POMERANIA         POMERANIA
# 2      PAT_1545       1867    NaN    NaN               NaN               NaN
# 3      PAT_1989       4061    NaN    NaN               NaN               NaN
# 4       PAT_684       1302  False   True         POMERANIA         POMERANIA
# ...         ...        ...    ...    ...               ...               ...
# 2293   PAT_1708       3156    NaN    NaN               NaN               NaN
# 2294     PAT_46        880  False  False         POMERANIA         POMERANIA
# 2295   PAT_1343       1217    NaN    NaN               NaN               NaN
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
# 2297   PAT_1714       3189    NaN    NaN               NaN               NaN
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/adedi/OneDrive - Solent University/Diss/Dissertation/Dataset/Source_2/metadata.csv')

# Visualization
# Count plot for diagnostic
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='diagnostic')
plt.title('Diagnostic Distribution for PH2 Dataset')
plt.xlabel('Diagnostic')
plt.ylabel('Count')

# Annotate counts on bars
for p in plt.gca().patches:
    plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# Count plot for gender
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='gender', hue='diagnostic')
plt.title('Diagnostic Distribution by Gender for PH2 Dataset')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Diagnostic')

# Annotate counts on bars
for p in plt.gca().patches:
    plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
    
plt.show()

# Box plot for age distribution by diagnostic
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='diagnostic', y='age')
plt.title('Age Distribution by Diagnostic for PH2 Dataset')
plt.xlabel('Diagnostic')
plt.ylabel('Age')

# Annotate counts on bars
for p in plt.gca().artists:
    p.set_edgecolor('k')  # set edge color for better visibility
    plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
df2 = pd.read_csv('C:/Users/adedi/OneDrive - Solent University/Diss/Dissertation/Dataset/Source_1_ISIC/ISBI2016_ISIC_Part3_Training_GroundTruth.csv')

df2

# Count plot for label
plt.figure(figsize=(8, 6))
sns.countplot(data=df2, x='Label', order=df2['Label'].value_counts().index)
plt.title('Distribution of Labels for ISIC 016 Dataset')
plt.xlabel('Label')
plt.ylabel('Count')

# Annotate counts on bars
for p in plt.gca().patches:
    plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()
